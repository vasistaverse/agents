# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
gemini_api_key = os.getenv('GEMINI_API_KEY')

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Gemini API Key exists and begins AIzaSyCu

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

geminiAi = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key=gemini_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses Gemini 2.5 Flash, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = geminiAi.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses Gemini 2.5 Mini, still cheap but more powerful than flash

response = geminiAi.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# There are three abstract transformations, $T_X, T_Y, T_Z$, which act on ordered 6-element sequences. The effect of each transformation is consistently defined, regardless of the sequence it is applied to. Their combined effects are shown below:
#
# **Example 1:**
# Initial Sequence: $(1, 2, 3, 4, 5, 6)$
# Applied Transformations (in order): $T_X$, then $T_Y$
# Final Sequence: $(4, 2, 1, 5, 3, 6)$
#
# **Example 2:**
# Initial Sequence: $(6, 5, 4, 3, 2, 1)$
# Applied Transformations (in order): $T_Y$, then $T_Z$
# Final Sequence: $(5, 6, 4, 2, 3, 1)$
#
# **Example 3:**
# Initial Sequence: $(1, 3, 5, 2, 4, 6)$
# Applied Transformations (in order): $T_Z$, then $T_X$
# Final Sequence: $(3, 5, 6, 1, 2, 4)$
#
# What is the Final Sequence for the following:
#
# **Question:**
# Initial Sequence: $(2, 4, 6, 1, 3, 5)$
# Applied Transformations (in order): $T_X$, then $T_Z$, then $T_Y$
# Final Sequence: ?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = geminiAi.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# The problem requires us to determine the individual transformations $T_X, T_Y, T_Z$ and then apply their composition to a given initial sequence. Let $P_X, P_Y, P_Z$ be the permutations representing these transformations. If an initial sequence is $S_{initial} = (s_1, s_2, s_3, s_4, s_5, s_6)$, and a transformation $P$ is applied, the resulting sequence $S_{final}$ is such that the element originally at position $j$ in $S_{initial}$ moves to position $P(j)$ in $S_{final}$. So, $S_{final}(P(j)) = S_{initial}(j)$.
#
# The composition of transformations means applying them sequentially. If $T_X$ is applied, then $T_Y$, the combined permutation is $P_Y \circ P_X$. This means an element initially at position $j$ moves to $P_X(j)$, and then that new position moves to $P_Y(P_X(j))$. So the final position is $P_Y(P_X(j))$.
#
# Let's extract the combined permutations from the examples:
#
# **Example 1: $T_X$, then $T_Y$**
# Initial Sequence: $(1, 2, 3, 4, 5, 6)$
# Final Sequence: $(4, 2, 1, 5, 3, 6)$
# Let $P_{XY} = P_Y \circ P_X$. We track where each initial element goes:
# - Element '1' (from pos 1) goes to pos 3. So $P_{XY}(1)=3$.
# - Element '2' (from pos 2) goes to pos 2. So $P_{XY}(2)=2$.
# - Element '3' (from pos 3) goes to pos 5. So $P_{XY}(3)=5$.
# - Element '4' (from pos 4) goes to pos 1. So $P_{XY}(4)=1$.
# - Element '5' (from pos 5) goes to pos 4. So $P_{XY}(5)=4$.
# - Element '6' (from pos 6) goes to pos 6. So $P_{XY}(6)=6$.
# So, $P_{XY} = [3, 2, 5, 1, 4, 6]$. In cycle notation: $A = (1~3~5~4)(2)(6) = (1~3~5~4)$.
#
# **Example 2: $T_Y$, then $T_Z$**
# Initial Sequence: $(6, 5, 4, 3, 2, 1)$
# Final Sequence: $(5, 6, 4, 2, 3, 1)$
# Let $P_{YZ} = P_Z \circ P_Y$. We track where each initial element goes:
# - Element '6' (from pos 1) goes to pos 2. So $P_{YZ}(1)=2$.
# - Element '5' (from pos 2) goes to pos 1. So $P_{YZ}(2)=1$.
# - Element '4' (from pos 3) goes to pos 3. So $P_{YZ}(3)=3$.
# - Element '3' (from pos 4) goes to pos 5. So $P_{YZ}(4)=5$.
# - Element '2' (from pos 5) goes to pos 4. So $P_{YZ}(5)=4$.
# - Element '1' (from pos 6) goes to pos 6. So $P_{YZ}(6)=6$.
# So, $P_{YZ} = [2, 1, 3, 5, 4, 6]$. In cycle notation: $B = (1~2)(3)(4~5)(6) = (1~2)(4~5)$.
#
# **Example 3: $T_Z$, then $T_X$**
# Initial Sequence: $(1, 3, 5, 2, 4, 6)$
# Final Sequence: $(3, 5, 6, 1, 2, 4)$
# Let $P_{ZX} = P_X \circ P_Z$. We track where each initial element goes:
# - Element '1' (from pos 1) goes to pos 4. So $P_{ZX}(1)=4$.
# - Element '3' (from pos 2) goes to pos 1. So $P_{ZX}(2)=1$.
# - Element '5' (from pos 3) goes to pos 2. So $P_{ZX}(3)=2$.
# - Element '2' (from pos 4) goes to pos 5. So $P_{ZX}(4)=5$.
# - Element '4' (from pos 5) goes to pos 6. So $P_{ZX}(5)=6$.
# - Element '6' (from pos 6) goes to pos 3. So $P_{ZX}(6)=3$.
# So, $P_{ZX} = [4, 1, 2, 5, 6, 3]$. In cycle notation: $C = (1~4~5~6~3~2)$.
#
# We have the following system of equations for the permutations $P_X, P_Y, P_Z$:
# 1. $P_Y \circ P_X = A = (1~3~5~4)$
# 2. $P_Z \circ P_Y = B = (1~2)(4~5)$
# 3. $P_X \circ P_Z = C = (1~4~5~6~3~2)$
#
# From (1), $P_Y = A \circ P_X^{-1}$.
# Substitute into (2): $P_Z \circ (A \circ P_X^{-1}) = B \implies P_Z = B \circ P_X \circ A^{-1}$.
# Substitute this $P_Z$ into (3): $P_X \circ (B \circ P_X \circ A^{-1}) = C$.
# This can be rewritten as $P_X \circ B \circ P_X = C \circ A$.
#
# First, calculate $C \circ A$:
# $A = [3,2,5,1,4,6]$
# $C = [4,1,2,5,6,3]$
# $C \circ A$:
# $(C \circ A)(1) = C(A(1)) = C(3) = 2$
# $(C \circ A)(2) = C(A(2)) = C(2) = 1$
# $(C \circ A)(3) = C(A(3)) = C(5) = 6$
# $(C \circ A)(4) = C(A(4)) = C(1) = 4$
# $(C \circ A)(5) = C(A(5)) = C(4) = 5$
# $(C \circ A)(6) = C(A(6)) = C(6) = 3$
# So, $C \circ A = [2,1,6,4,5,3] = (1~2)(3~6)$.
#
# Now we need to solve $P_X \circ B \circ P_X = (1~2)(3~6)$.
# This is equivalent to $P_X B P_X^{-1} = (1~2)(3~6)$ if we consider $P_X$ as a permutation.
# $B = (1~2)(4~5)$. When a permutation $B$ is conjugated by $P_X$, the resulting cycles are $P_X$ applied to the elements of $B$'s cycles.
# So, $(P_X(1)~P_X(2))(P_X(4)~P_X(5)) = (1~2)(3~6)$.
# This means either:
# Case 1: $P_X(1)=1, P_X(2)=2$ and $P_X(4)=3, P_X(5)=6$. Since $B(3)=3, B(6)=6$, $P_X(3)$ and $P_X(6)$ must be fixed points of $(1~2)(3~6)$, i.e., $4$ and $5$. So $P_X(3)=4, P_X(6)=5$.
# This gives $P_X = [1,2,4,3,6,5]$. In cycle notation: $P_X = (3~4)(5~6)$.
# Case 2: $P_X(1)=3, P_X(2)=6$ and $P_X(4)=1, P_X(5)=2$. Again, $P_X(3)=4, P_X(6)=5$.
# This gives $P_X = [3,6,4,1,2,5]$. In cycle notation: $P_X = (1~3~4)(2~6~5)$.
#
# Let's test Case 1: $P_X = (3~4)(5~6) = [1,2,4,3,6,5]$.
# Then $P_X^{-1} = P_X$.
# $P_Y = A \circ P_X^{-1} = (1~3~5~4) \circ (3~4)(5~6)$.
# $(P_Y)(1)=3$, $(P_Y)(2)=2$, $(P_Y)(3)=1$, $(P_Y)(4)=5$, $(P_Y)(5)=6$, $(P_Y)(6)=4$.
# So $P_Y = [3,2,1,5,6,4] = (1~3)(4~5~6)$.
#
# $P_Z = B \circ P_Y^{-1}$.
# $P_Y^{-1} = (1~3)(4~6~5) = [3,2,1,6,4,5]$.
# $P_Z(1)=B(P_Y^{-1}(1))=B(3)=3$.
# $P_Z(2)=B(P_Y^{-1}(2))=B(2)=1$.
# $P_Z(3)=B(P_Y^{-1}(3))=B(1)=2$.
# $P_Z(4)=B(P_Y^{-1}(4))=B(6)=6$.
# $P_Z(5)=B(P_Y^{-1}(5))=B(4)=5$.
# $P_Z(6)=B(P_Y^{-1}(6))=B(5)=4$.
# So $P_Z = [3,1,2,6,5,4] = (1~3~2)(4~6)$.
#
# Let's verify these permutations with $P_X \circ P_Z = C$:
# $P_X \circ P_Z = (3~4)(5~6) \circ (1~3~2)(4~6)$.
# $(P_X \circ P_Z)(1) = P_X(P_Z(1)) = P_X(3) = 4$.
# $(P_X \circ P_Z)(2) = P_X(P_Z(2)) = P_X(1) = 1$.
# $(P_X \circ P_Z)(3) = P_X(P_Z(3)) = P_X(2) = 2$.
# $(P_X \circ P_Z)(4) = P_X(P_Z(4)) = P_X(6) = 5$.
# $(P_X \circ P_Z)(5) = P_X(P_Z(5)) = P_X(5) = 6$.
# $(P_X \circ P_Z)(6) = P_X(P_Z(6)) = P_X(4) = 3$.
# So $P_X \circ P_Z = [4,1,2,5,6,3]$, which is $C = (1~4~5~6~3~2)$. This set of permutations is consistent.
#
# (We can show that Case 2 would lead to inconsistency, so the permutations are unique.)
#
# The individual transformations are:
# $P_X = (3~4)(5~6) = [1,2,4,3,6,5]$
# $P_Y = (1~3)(4~5~6) = [3,2,1,5,6,4]$
# $P_Z = (1~3~2)(4~6) = [3,1,2,6,5,4]$
#
# **Calculate the Final Sequence for the Question:**
# Initial Sequence: $(2, 4, 6, 1, 3, 5)$
# Applied Transformations (in order): $T_X$, then $T_Z$, then $T_Y$.
# This corresponds to the permutation $P_{total} = P_Y \circ P_Z \circ P_X$.
#
# First, calculate $P_Z \circ P_X$:
# $(P_Z \circ P_X)(1) = P_Z(P_X(1)) = P_Z(1) = 3$.
# $(P_Z \circ P_X)(2) = P_Z(P_X(2)) = P_Z(2) = 1$.
# $(P_Z \circ P_X)(3) = P_Z(P_X(3)) = P_Z(4) = 6$.
# $(P_Z \circ P_X)(4) = P_Z(P_X(4)) = P_Z(3) = 2$.
# $(P_Z \circ P_X)(5) = P_Z(P_X(5)) = P_Z(6) = 4$.
# $(P_Z \circ P_X)(6) = P_Z(P_X(6)) = P_Z(5) = 5$.
# So $P_Z \circ P_X = [3,1,6,2,4,5]$. In cycle notation: $(1~3~6~5~4~2)$.
#
# Next, calculate $P_{total} = P_Y \circ (P_Z \circ P_X)$:
# Let $P_{ZX} = P_Z \circ P_X = [3,1,6,2,4,5]$.
# $(P_{total})(1) = P_Y(P_{ZX}(1)) = P_Y(3) = 1$.
# $(P_{total})(2) = P_Y(P_{ZX}(2)) = P_Y(1) = 3$.
# $(P_{total})(3) = P_Y(P_{ZX}(3)) = P_Y(6) = 4$.
# $(P_{total})(4) = P_Y(P_{ZX}(4)) = P_Y(2) = 2$.
# $(P_{total})(5) = P_Y(P_{ZX}(5)) = P_Y(4) = 5$.
# $(P_{total})(6) = P_Y(P_{ZX}(6)) = P_Y(5) = 6$.
# So $P_{total} = [1,3,4,2,5,6]$. In cycle notation: $(2~3~4)$. (1, 5, 6 are fixed points).
#
# Now, apply $P_{total}$ to the initial sequence $S_{initial} = (2, 4, 6, 1, 3, 5)$.
# Let $S_{final}$ be the final sequence. $S_{final}(P_{total}(j)) = S_{initial}(j)$.
# - $P_{total}(1)=1 \implies S_{final}(1) = S_{initial}(1) = 2$.
# - $P_{total}(2)=3 \implies S_{final}(3) = S_{initial}(2) = 4$.
# - $P_{total}(3)=4 \implies S_{final}(4) = S_{initial}(3) = 6$.
# - $P_{total}(4)=2 \implies S_{final}(2) = S_{initial}(4) = 1$.
# - $P_{total}(5)=5 \implies S_{final}(5) = S_{initial}(5) = 3$.
# - $P_{total}(6)=6 \implies S_{final}(6) = S_{initial}(6) = 5$.
#
# Assembling the final sequence:
# $S_{final} = (S_{final}(1), S_{final}(2), S_{final}(3), S_{final}(4), S_{final}(5), S_{final}(6))$
# $S_{final} = (2, 1, 4, 6, 3, 5)$.
#
# The final answer is $\boxed{(2, 1, 4, 6, 3, 5)}$

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# The problem requires us to determine the individual transformations $T_X, T_Y, T_Z$ and then apply their composition to a given initial sequence. Let $P_X, P_Y, P_Z$ be the permutations representing these transformations. If an initial sequence is $S_{initial} = (s_1, s_2, s_3, s_4, s_5, s_6)$, and a transformation $P$ is applied, the resulting sequence $S_{final}$ is such that the element originally at position $j$ in $S_{initial}$ moves to position $P(j)$ in $S_{final}$. So, $S_{final}(P(j)) = S_{initial}(j)$.
#
# The composition of transformations means applying them sequentially. If $T_X$ is applied, then $T_Y$, the combined permutation is $P_Y \circ P_X$. This means an element initially at position $j$ moves to $P_X(j)$, and then that new position moves to $P_Y(P_X(j))$. So the final position is $P_Y(P_X(j))$.
#
# Let's extract the combined permutations from the examples:
#
# **Example 1: $T_X$, then $T_Y$**
# Initial Sequence: $(1, 2, 3, 4, 5, 6)$
# Final Sequence: $(4, 2, 1, 5, 3, 6)$
# Let $P_{XY} = P_Y \circ P_X$. We track where each initial element goes:
# - Element '1' (from pos 1) goes to pos 3. So $P_{XY}(1)=3$.
# - Element '2' (from pos 2) goes to pos 2. So $P_{XY}(2)=2$.
# - Element '3' (from pos 3) goes to pos 5. So $P_{XY}(3)=5$.
# - Element '4' (from pos 4) goes to pos 1. So $P_{XY}(4)=1$.
# - Element '5' (from pos 5) goes to pos 4. So $P_{XY}(5)=4$.
# - Element '6' (from pos 6) goes to pos 6. So $P_{XY}(6)=6$.
# So, $P_{XY} = [3, 2, 5, 1, 4, 6]$. In cycle notation: $A = (1~3~5~4)(2)(6) = (1~3~5~4)$.
#
# **Example 2: $T_Y$, then $T_Z$**
# Initial Sequence: $(6, 5, 4, 3, 2, 1)$
# Final Sequence: $(5, 6, 4, 2, 3, 1)$
# Let $P_{YZ} = P_Z \circ P_Y$. We track where each initial element goes:
# - Element '6' (from pos 1) goes to pos 2. So $P_{YZ}(1)=2$.
# - Element '5' (from pos 2) goes to pos 1. So $P_{YZ}(2)=1$.
# - Element '4' (from pos 3) goes to pos 3. So $P_{YZ}(3)=3$.
# - Element '3' (from pos 4) goes to pos 5. So $P_{YZ}(4)=5$.
# - Element '2' (from pos 5) goes to pos 4. So $P_{YZ}(5)=4$.
# - Element '1' (from pos 6) goes to pos 6. So $P_{YZ}(6)=6$.
# So, $P_{YZ} = [2, 1, 3, 5, 4, 6]$. In cycle notation: $B = (1~2)(3)(4~5)(6) = (1~2)(4~5)$.
#
# **Example 3: $T_Z$, then $T_X$**
# Initial Sequence: $(1, 3, 5, 2, 4, 6)$
# Final Sequence: $(3, 5, 6, 1, 2, 4)$
# Let $P_{ZX} = P_X \circ P_Z$. We track where each initial element goes:
# - Element '1' (from pos 1) goes to pos 4. So $P_{ZX}(1)=4$.
# - Element '3' (from pos 2) goes to pos 1. So $P_{ZX}(2)=1$.
# - Element '5' (from pos 3) goes to pos 2. So $P_{ZX}(3)=2$.
# - Element '2' (from pos 4) goes to pos 5. So $P_{ZX}(4)=5$.
# - Element '4' (from pos 5) goes to pos 6. So $P_{ZX}(5)=6$.
# - Element '6' (from pos 6) goes to pos 3. So $P_{ZX}(6)=3$.
# So, $P_{ZX} = [4, 1, 2, 5, 6, 3]$. In cycle notation: $C = (1~4~5~6~3~2)$.
#
# We have the following system of equations for the permutations $P_X, P_Y, P_Z$:
# 1. $P_Y \circ P_X = A = (1~3~5~4)$
# 2. $P_Z \circ P_Y = B = (1~2)(4~5)$
# 3. $P_X \circ P_Z = C = (1~4~5~6~3~2)$
#
# From (1), $P_Y = A \circ P_X^{-1}$.
# Substitute into (2): $P_Z \circ (A \circ P_X^{-1}) = B \implies P_Z = B \circ P_X \circ A^{-1}$.
# Substitute this $P_Z$ into (3): $P_X \circ (B \circ P_X \circ A^{-1}) = C$.
# This can be rewritten as $P_X \circ B \circ P_X = C \circ A$.
#
# First, calculate $C \circ A$:
# $A = [3,2,5,1,4,6]$
# $C = [4,1,2,5,6,3]$
# $C \circ A$:
# $(C \circ A)(1) = C(A(1)) = C(3) = 2$
# $(C \circ A)(2) = C(A(2)) = C(2) = 1$
# $(C \circ A)(3) = C(A(3)) = C(5) = 6$
# $(C \circ A)(4) = C(A(4)) = C(1) = 4$
# $(C \circ A)(5) = C(A(5)) = C(4) = 5$
# $(C \circ A)(6) = C(A(6)) = C(6) = 3$
# So, $C \circ A = [2,1,6,4,5,3] = (1~2)(3~6)$.
#
# Now we need to solve $P_X \circ B \circ P_X = (1~2)(3~6)$.
# This is equivalent to $P_X B P_X^{-1} = (1~2)(3~6)$ if we consider $P_X$ as a permutation.
# $B = (1~2)(4~5)$. When a permutation $B$ is conjugated by $P_X$, the resulting cycles are $P_X$ applied to the elements of $B$'s cycles.
# So, $(P_X(1)~P_X(2))(P_X(4)~P_X(5)) = (1~2)(3~6)$.
# This means either:
# Case 1: $P_X(1)=1, P_X(2)=2$ and $P_X(4)=3, P_X(5)=6$. Since $B(3)=3, B(6)=6$, $P_X(3)$ and $P_X(6)$ must be fixed points of $(1~2)(3~6)$, i.e., $4$ and $5$. So $P_X(3)=4, P_X(6)=5$.
# This gives $P_X = [1,2,4,3,6,5]$. In cycle notation: $P_X = (3~4)(5~6)$.
# Case 2: $P_X(1)=3, P_X(2)=6$ and $P_X(4)=1, P_X(5)=2$. Again, $P_X(3)=4, P_X(6)=5$.
# This gives $P_X = [3,6,4,1,2,5]$. In cycle notation: $P_X = (1~3~4)(2~6~5)$.
#
# Let's test Case 1: $P_X = (3~4)(5~6) = [1,2,4,3,6,5]$.
# Then $P_X^{-1} = P_X$.
# $P_Y = A \circ P_X^{-1} = (1~3~5~4) \circ (3~4)(5~6)$.
# $(P_Y)(1)=3$, $(P_Y)(2)=2$, $(P_Y)(3)=1$, $(P_Y)(4)=5$, $(P_Y)(5)=6$, $(P_Y)(6)=4$.
# So $P_Y = [3,2,1,5,6,4] = (1~3)(4~5~6)$.
#
# $P_Z = B \circ P_Y^{-1}$.
# $P_Y^{-1} = (1~3)(4~6~5) = [3,2,1,6,4,5]$.
# $P_Z(1)=B(P_Y^{-1}(1))=B(3)=3$.
# $P_Z(2)=B(P_Y^{-1}(2))=B(2)=1$.
# $P_Z(3)=B(P_Y^{-1}(3))=B(1)=2$.
# $P_Z(4)=B(P_Y^{-1}(4))=B(6)=6$.
# $P_Z(5)=B(P_Y^{-1}(5))=B(4)=5$.
# $P_Z(6)=B(P_Y^{-1}(6))=B(5)=4$.
# So $P_Z = [3,1,2,6,5,4] = (1~3~2)(4~6)$.
#
# Let's verify these permutations with $P_X \circ P_Z = C$:
# $P_X \circ P_Z = (3~4)(5~6) \circ (1~3~2)(4~6)$.
# $(P_X \circ P_Z)(1) = P_X(P_Z(1)) = P_X(3) = 4$.
# $(P_X \circ P_Z)(2) = P_X(P_Z(2)) = P_X(1) = 1$.
# $(P_X \circ P_Z)(3) = P_X(P_Z(3)) = P_X(2) = 2$.
# $(P_X \circ P_Z)(4) = P_X(P_Z(4)) = P_X(6) = 5$.
# $(P_X \circ P_Z)(5) = P_X(P_Z(5)) = P_X(5) = 6$.
# $(P_X \circ P_Z)(6) = P_X(P_Z(6)) = P_X(4) = 3$.
# So $P_X \circ P_Z = [4,1,2,5,6,3]$, which is $C = (1~4~5~6~3~2)$. This set of permutations is consistent.
#
# (We can show that Case 2 would lead to inconsistency, so the permutations are unique.)
#
# The individual transformations are:
# $P_X = (3~4)(5~6) = [1,2,4,3,6,5]$
# $P_Y = (1~3)(4~5~6) = [3,2,1,5,6,4]$
# $P_Z = (1~3~2)(4~6) = [3,1,2,6,5,4]$
#
# **Calculate the Final Sequence for the Question:**
# Initial Sequence: $(2, 4, 6, 1, 3, 5)$
# Applied Transformations (in order): $T_X$, then $T_Z$, then $T_Y$.
# This corresponds to the permutation $P_{total} = P_Y \circ P_Z \circ P_X$.
#
# First, calculate $P_Z \circ P_X$:
# $(P_Z \circ P_X)(1) = P_Z(P_X(1)) = P_Z(1) = 3$.
# $(P_Z \circ P_X)(2) = P_Z(P_X(2)) = P_Z(2) = 1$.
# $(P_Z \circ P_X)(3) = P_Z(P_X(3)) = P_Z(4) = 6$.
# $(P_Z \circ P_X)(4) = P_Z(P_X(4)) = P_Z(3) = 2$.
# $(P_Z \circ P_X)(5) = P_Z(P_X(5)) = P_Z(6) = 4$.
# $(P_Z \circ P_X)(6) = P_Z(P_X(6)) = P_Z(5) = 5$.
# So $P_Z \circ P_X = [3,1,6,2,4,5]$. In cycle notation: $(1~3~6~5~4~2)$.
#
# Next, calculate $P_{total} = P_Y \circ (P_Z \circ P_X)$:
# Let $P_{ZX} = P_Z \circ P_X = [3,1,6,2,4,5]$.
# $(P_{total})(1) = P_Y(P_{ZX}(1)) = P_Y(3) = 1$.
# $(P_{total})(2) = P_Y(P_{ZX}(2)) = P_Y(1) = 3$.
# $(P_{total})(3) = P_Y(P_{ZX}(3)) = P_Y(6) = 4$.
# $(P_{total})(4) = P_Y(P_{ZX}(4)) = P_Y(2) = 2$.
# $(P_{total})(5) = P_Y(P_{ZX}(5)) = P_Y(4) = 5$.
# $(P_{total})(6) = P_Y(P_{ZX}(6)) = P_Y(5) = 6$.
# So $P_{total} = [1,3,4,2,5,6]$. In cycle notation: $(2~3~4)$. (1, 5, 6 are fixed points).
#
# Now, apply $P_{total}$ to the initial sequence $S_{initial} = (2, 4, 6, 1, 3, 5)$.
# Let $S_{final}$ be the final sequence. $S_{final}(P_{total}(j)) = S_{initial}(j)$.
# - $P_{total}(1)=1 \implies S_{final}(1) = S_{initial}(1) = 2$.
# - $P_{total}(2)=3 \implies S_{final}(3) = S_{initial}(2) = 4$.
# - $P_{total}(3)=4 \implies S_{final}(4) = S_{initial}(3) = 6$.
# - $P_{total}(4)=2 \implies S_{final}(2) = S_{initial}(4) = 1$.
# - $P_{total}(5)=5 \implies S_{final}(5) = S_{initial}(5) = 3$.
# - $P_{total}(6)=6 \implies S_{final}(6) = S_{initial}(6) = 5$.
#
# Assembling the final sequence:
# $S_{final} = (S_{final}(1), S_{final}(2), S_{final}(3), S_{final}(4), S_{final}(5), S_{final}(6))$
# $S_{final} = (2, 1, 4, 6, 3, 5)$.
#
# The final answer is $\boxed{(2, 1, 4, 6, 3, 5)}$

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business idea for a startup in the AI space, and explain it in detail."}]

# Then make the first call:

response = geminiAi.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# Okay, let's dive into an AI startup idea that addresses a significant and growing need.
#
# ---
#
# ## AI Startup Idea: SkillPath AI: Adaptive Learning for Technical Mastery
#
# ### 1. The Problem: The Skills Gap & Ineffective Learning
#
# The world is changing rapidly, especially in technology. Companies constantly need new skills (AI/ML, Data Science, Cybersecurity, Cloud Computing, Advanced Software Development), but:
#
# *   **Existing online learning platforms are often one-size-fits-all:** They offer static courses, leading to high dropout rates because content isn't tailored to individual learning styles, prior knowledge, or career goals.
# *   **Traditional education is slow to adapt:** Universities struggle to keep pace with industry demands, leaving graduates underprepared.
# *   **Bootcamps are expensive and intense:** While effective for some, they lack true personalization and can be overwhelming.
# *   **Learners struggle with "what next?":** They often don't know the most efficient path to acquire a new skill or how to bridge gaps in their current knowledge effectively.
# *   **Companies face massive reskilling challenges:** Training large workforces in new technologies is costly, time-consuming, and often ineffective due to generic training programs.
#
# ### 2. The Solution: Hyper-Personalized, AI-Driven Technical Skill Development
#
# **SkillPath AI** is an adaptive learning platform that uses advanced AI to create highly personalized, project-based learning paths for individuals and enterprises seeking to master in-demand technical skills.
#
# Instead of static courses, SkillPath AI builds a dynamic, evolving curriculum unique to each user, acting as an always-on, intelligent tutor and career guide.
#
# ### 3. How AI Powers SkillPath AI (Core AI Components)
#
# The AI is central to every aspect of the platform:
#
# 1.  **Initial Skill & Learning Style Assessment (Predictive AI & NLP):**
#     *   Upon signup, users provide their resume/LinkedIn, career goals, and complete a series of adaptive tests (coding challenges, multiple-choice, concept explanations).
#     *   **AI Function:** Natural Language Processing (NLP) extracts skills and experience from resumes. A predictive model analyzes test performance, identifies existing strengths/weaknesses, and infers preferred learning styles (visual, auditory, kinesthetic, conceptual). This creates a detailed "learner profile."
#
# 2.  **Dynamic Curriculum Generation (Reinforcement Learning & Recommender Systems):**
#     *   Based on the learner profile and chosen target skill (e.g., "Become a Python Data Scientist"), the AI generates an optimal, step-by-step learning path.
#     *   **AI Function:** A reinforcement learning model continuously optimizes the sequence of modules, projects, and resources. It considers prerequisites, interdependencies, and the estimated time to mastery. A sophisticated recommender system selects the most relevant content pieces (lectures, readings, interactive labs, projects) from SkillPath AI's vast library, personalized to the user's inferred learning style and pace.
#
# 3.  **Adaptive Content Delivery & Resource Selection (Multi-modal AI):**
#     *   If the AI detects a user struggles with a concept, it doesn't just repeat the same explanation.
#     *   **AI Function:** It dynamically switches content formats (e.g., if a user struggles with a text explanation, it might suggest a different video tutorial, an interactive coding exercise, or a gamified challenge). It can even generate *new* explanations or examples on the fly using Generative AI (LLMs), tailored to the user's specific point of confusion or a real-world scenario they've previously expressed interest in.
#
# 4.  **Intelligent Tutoring & Real-time Feedback (Generative AI & Code Analysis):**
#     *   Users work on practical projects within an integrated development environment (IDE).
#     *   **AI Function:**
#         *   **Code Review:** An AI-powered code analyzer provides instant, granular feedback on syntax errors, logical bugs, best practices, and efficiency improvements, explaining *why* a suggestion is made.
#         *   **Concept Clarification:** Users can ask the AI tutor questions about any concept or piece of code, receiving immediate, context-aware explanations, analogies, or links to relevant resources. This is powered by a fine-tuned LLM.
#         *   **Debugging Assistance:** The AI can guide users through debugging steps, asking leading questions rather than just giving answers, fostering problem-solving skills.
#
# 5.  **Progress Monitoring & Predictive Analytics (Machine Learning):**
#     *   The platform constantly tracks user engagement, performance on assignments, time spent, and sentiment (inferred from interaction patterns).
#     *   **AI Function:** Machine learning models predict potential areas of struggle or disengagement *before* they occur. It can proactively suggest review modules, recommend a brief break, or flag the need for human mentor intervention (if the subscription tier includes it). It also provides insights into a user's mastery level across different sub-skills.
#
# 6.  **Content Curation & Update Automation (NLP & Web Scraping):**
#     *   The tech landscape evolves rapidly.
#     *   **AI Function:** NLP models continuously monitor industry trends, job descriptions, and new research papers to identify emerging skills and update existing content for relevance. It can suggest new topics for curriculum development or flag outdated information.
#
# ### 4. Target Market
#
# *   **Individuals (B2C):**
#     *   Career changers looking to enter tech.
#     *   Existing tech professionals wanting to upskill or specialize.
#     *   Recent graduates needing to bridge the gap between academia and industry.
#     *   Freelancers needing to stay competitive.
# *   **Enterprises (B2B):**
#     *   Tech companies needing to reskill or upskill their engineering, data, or product teams.
#     *   Consulting firms requiring their talent to master new technologies quickly.
#     *   Any large organization looking to build in-house technical capabilities.
#
# ### 5. Business Model
#
# *   **Subscription (B2C):** Tiered pricing (e.g., Basic Access, Premium with advanced AI tutoring/project review, Ultimate with human mentor sessions and career coaching).
# *   **Enterprise Licensing (B2B):** Per-seat licenses for companies, including custom content integration, dedicated analytics dashboards for HR/L&D, and custom reporting on skill progression.
# *   **Certification Fees:** Offer industry-recognized certifications for various skill paths (potentially partnered with industry leaders).
# *   **Skill Audit Services (B2B):** Use the AI's assessment capabilities to provide companies with a detailed report on their workforce's current skill landscape and identify critical gaps.
#
# ### 6. Competitive Advantage
#
# *   **Unparalleled Personalization:** Goes far beyond "adaptive" paths by truly customizing *how* content is delivered, *what* feedback is given, and *when* interventions occur.
# *   **AI-Driven Efficiency:** Accelerates learning by optimizing paths and providing instant, targeted support, reducing time to mastery.
# *   **Project-First Approach:** Focuses on practical application, making learning more engaging and skills more immediately applicable.
# *   **Always-On Intelligent Tutor:** Learners are never stuck; the AI is always there to guide, explain, and provide feedback.
# *   **Proactive Skill Gap Identification:** For both individuals and enterprises, the AI can foresee skill deficiencies.
# *   **Scalability:** The AI scales with the number of users without a linear increase in human instructor costs.
#
# ### 7. Key Challenges & Risks
#
# *   **Data Acquisition & Quality:** Training the initial AI models requires a massive dataset of learning interactions, content, and learner profiles.
# *   **Model Accuracy & Bias:** Ensuring the AI's recommendations and feedback are accurate, fair, and free from biases in content or assessment.
# *   **Content Curation & Creation:** Maintaining a high-quality, up-to-date, and comprehensive library of technical content.
# *   **User Trust & Adoption:** Overcoming skepticism about AI-led learning and ensuring a seamless, intuitive user experience.
# *   **Competition:** From established players like Coursera, Udemy, Pluralsight, and emerging AI education tools.
# *   **Technological Evolution:** The very skills being taught (and the AI technology used) are constantly evolving, requiring continuous updates to the platform's core.
#
# ### 8. Future Potential
#
# *   **Expanded Skill Domains:** Beyond technical skills to leadership, creative, or soft skills.
# *   **Immersive Learning:** Integration with AR/VR for highly realistic simulated environments for hands-on practice (e.g., debugging a virtual server rack).
# *   **Direct Job Matching:** Using the detailed skill profile to match users with relevant job opportunities and even generate personalized resume/cover letter suggestions.
# *   **Collaboration Features:** AI-facilitated team projects where the AI acts as a project manager, guiding collaboration and assessing individual contributions within a team context.
#
# ---
#
# SkillPath AI represents a powerful leap forward in how we acquire and master complex technical skills, leveraging the full potential of modern AI to create a truly personalized and effective learning journey.

# %%
messages = [{"role": "user", "content": f"Here's a business idea: {business_idea}. Now, can you come up with different pain points in this idea?"}]

pain_points = geminiAi.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

# %%
display(Markdown(pain_points.choices[0].message.content))
# Out:
# This is a strong, well-articulated business idea with a clear vision and thoughtful integration of AI. However, even the best ideas have potential vulnerabilities and challenges that can become "pain points" during development, launch, and scaling.
#
# Here are some different pain points specific to the **SkillPath AI** idea:
#
# ---
#
# ### Pain Points for SkillPath AI:
#
# 1.  **The "Cold Start" Problem for Personalization & Trust:**
#     *   **Challenge:** The initial skill assessment (resumes, LinkedIn, adaptive tests) is crucial. If the AI's initial interpretation of a user's abilities, goals, or learning style is inaccurate, the "hyper-personalized" path generated will be suboptimal, leading to early user frustration and distrust.
#     *   **Why it hurts:** New users might drop off quickly if their initial experience doesn't feel genuinely tailored or if the recommendations seem off-base. Without enough initial data, the AI's predictions might be generic or biased, undermining the core value proposition.
#
# 2.  **Maintaining Content Quality and Freshness at Scale with AI:**
#     *   **Challenge:** While AI can assist with content curation and updates, a "vast library" of high-quality, pedagogically sound, and *constantly evolving* technical content is a monumental undertaking. Generative AI for explanations is powerful, but ensuring its accuracy, pedagogical effectiveness, and stylistic consistency across diverse topics is incredibly difficult.
#     *   **Why it hurts:** Incorrect AI-generated explanations, outdated core content that the AI *missed*, or a lack of depth in niche areas will quickly diminish the platform's credibility and effectiveness, especially in fast-moving tech fields. Human oversight will still be massive.
#
# 3.  **The "Human Touch" vs. AI-Only Learning Plateau:**
#     *   **Challenge:** Many learners thrive on human interaction – direct mentorship, peer collaboration, the accountability of a live instructor, and the ability to ask nuanced questions that an AI might misinterpret. While SkillPath AI offers "intelligent tutoring," there's a psychological gap between an AI explanation and a human mentor's empathy and experience.
#     *   **Why it hurts:** Learners might hit a plateau where the AI can no longer provide the qualitative leap in understanding or motivation that a human connection could. This could lead to churn, especially in advanced topics or when facing complex, ambiguous real-world problems. The ultimate tier with "human mentor sessions" acknowledges this, but suggests a limitation of the core AI-only offering.
#
# 4.  **High Development & Sustained Compute Costs for Advanced AI:**
#     *   **Challenge:** Building, training, and *continuously updating* the proposed suite of sophisticated AI models (Reinforcement Learning, NLP, Multi-modal AI, Generative AI for dynamic content, advanced code analysis) requires a vast team of highly paid AI researchers and engineers. Furthermore, running these models at scale for potentially millions of users will incur significant, ongoing cloud computing expenses.
#     *   **Why it hurts:** This is a capital-intensive venture. The runway needed before profitability will be substantial, and the ongoing operational costs could eat into margins or force high subscription prices, making it less competitive.
#
# 5.  **AI Hallucinations and Misinterpretations in Critical Contexts (Tutoring & Code Review):**
#     *   **Challenge:** While Generative AI is powerful, it's prone to "hallucinations" – confidently presenting incorrect information. In a learning context, especially for complex technical skills, a hallucinated explanation or a misinformed code review can be incredibly detrimental, teaching bad practices or leading learners down wrong paths.
#     *   **Why it hurts:** Trust is paramount in education. If users encounter incorrect information or receive unhelpful debugging advice from the AI tutor, they will quickly lose faith in the platform's ability to guide them effectively, leading to churn and negative word-of-mouth.
#
# 6.  **Enterprise Adoption Barriers: Security, Data Privacy, and ROI Proving:**
#     *   **Challenge:** Companies are highly sensitive about their intellectual property and employee data. Integrating a third-party AI platform for reskilling requires significant trust in data security, privacy compliance (GDPR, CCPA), and control over proprietary content used for training. Proving a clear, measurable ROI on AI-driven training compared to traditional methods can also be a hurdle for L&D departments.
#     *   **Why it hurts:** Despite the promise of "massive reskilling challenges," enterprises might be slow to adopt due to these legitimate concerns, especially regarding their highly sensitive workforce data and the potential for skill data to be used in ways they don't approve of.
#
# 7.  **Over-Optimization Leading to "Filter Bubbles" in Learning:**
#     *   **Challenge:** If the AI is *too* good at personalizing content based on inferred learning styles and preferences, it might inadvertently create a "filter bubble." Users might only be exposed to content and teaching methods that the AI *thinks* they prefer, potentially limiting their exposure to diverse perspectives, alternative approaches, or different learning strategies that could actually broaden their understanding in the long run.
#     *   **Why it hurts:** While personalization is key, rigid adherence to it might stifle holistic skill development, critical thinking, and the ability to adapt to different teaching styles – skills often crucial in real-world technical roles.
#
# 8.  **Competition from "Good Enough" AI Features in Existing Platforms:**
#     *   **Challenge:** While SkillPath AI aims for "unparalleled personalization," established players (Coursera, Udemy, Pluralsight) and even new entrants are rapidly integrating AI features (AI-powered search, content recommendations, basic LLM tutors). These existing platforms have massive content libraries, established user bases, and brand recognition.
#     *   **Why it hurts:** Users might perceive the incremental benefit of SkillPath AI's deeper personalization as not worth the switch, especially if competitors offer "good enough" AI features at a lower price point or within an ecosystem they already use. Capturing market share will require a truly transformative experience.
#
# These pain points highlight areas where the technical ambition, user psychology, and market realities could create significant obstacles for SkillPath AI. Addressing them proactively will be critical for success.

# %% [markdown]
# messages = [{"role": "user", "content" : f"give me solutions the below pain points summary: "}]
